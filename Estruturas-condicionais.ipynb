# %% [markdown]
# <a href="https://colab.research.google.com/github/IsaqueCR4/Estruturas-condicionais/blob/main/Estruturas-condicionais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = int(input("Digite sua idade: "))

# Verificação da idade usando if, elif e else
if idade < 12:
    print("Entrada não permitida! Evento indicado para maiores de 12 anos.")
elif idade >= 12 and idade < 18:
    print("Entrada permitida somente com a presença de um responsável.")
else:
    print("Entrada liberada! Aproveite o evento.")

# Mensagem final
print("Obrigado por utilizar o sistema de verificação!")
# Out:
# Digite sua idade: 12
# Entrada permitida somente com a presença de um responsável.
# Obrigado por utilizar o sistema de verificação!
